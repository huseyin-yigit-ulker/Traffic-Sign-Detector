# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install ultralytics==8.0.26
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task =  detect  mode = train model = yolov8l.pt data = "/content/gdrive/MyDrive/Colab Notebooks/Traffic_Sign_Detection/Dataset/data.yaml" epochs = 50 imgsz = 700
# Out:
# Ultralytics YOLOv8.0.26 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import datetime

# %%
date = datetime.datetime.now()

# %%
date
# Out:
# datetime.datetime(2023, 5, 23, 21, 50, 10, 648220)

# %%
file_name = f'{date.year}-{date.month}-{date.day}_{date.hour+3}_{date.minute}_run'

# %%
import os

# %%
os.rename("runs",file_name)

# %%
file_name
# Out:
# '2023-5-23_24_50_run'

# %%
files.download("/content/2023-5-23_24_50_run")

# %%
from google.colab import files
files.download(f'/content/{file_name}/detect/train5/weights/best.pt')

# %%
files.download(f'/content/{file_name}/detect/train5/weights/last.pt')
