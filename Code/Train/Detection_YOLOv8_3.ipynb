# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install ultralytics==8.0.26
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.6/271.6 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task =  detect  mode = train model = yolov8l.pt data = "/content/gdrive/MyDrive/Colab Notebooks/Traffic_Sign_Detection/Dataset2/data.yaml" epochs = 25 imgsz = 700
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 237MB/s]
# Ultralytics YOLOv8.0.26 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import datetime

# %%
date = datetime.datetime.now()

# %%
date
# Out:
# datetime.datetime(2023, 5, 24, 21, 32, 24, 648037)

# %%
file_name = f'{date.year}-{date.month}-{date.day}_{date.hour+3}_{date.minute}_run'

# %%
import os
from google.colab import files

# %%
os.rename("runs",file_name)

# %%
files.download(f'/content/{file_name}')

# %%
files.download(f'/content/{file_name}/detect/train/weights/last.pt')
