# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install ultralytics==8.0.26
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.6/271.6 kB 24.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 24.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task =  detect  mode = train model = yolov8l.pt data = "/content/gdrive/MyDrive/Colab Notebooks/Traffic_Sign_Detection/Augmented_Data/data.yaml" epochs = 30 imgsz = 600
# Out:
# Ultralytics YOLOv8.0.26 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# 30 epoch 2 saat sürdü

# %%
import datetime

# %%
date = datetime.datetime.now()

# %%
date
# Out:
# datetime.datetime(2023, 5, 19, 13, 46, 14, 458832)

# %%
file_name = f'{date.year}-{date.month}-{date.day}_{date.hour+3}_{date.minute}_run'
# Out:
# '2023-5-19_16_46_run'

# %%
import os

# %%
os.rename("runs",file_name)

# %%
files.download(f'/content/{file_name}')

# %%
from google.colab import files
files.download(f'/content/{file_name}/detect/train2/weights/best.pt')
