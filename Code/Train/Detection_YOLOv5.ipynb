# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install ultralytics==8.0.26
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.6/271.6 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 23.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 58.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task =  detect  mode = train model = yolov5l.pt data = "/content/gdrive/MyDrive/Colab Notebooks/Traffic_Sign_Detection/Dataset3/data.yaml" epochs = 30 imgsz = 600
# Out:
# PRO TIP 💡 Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 102M/102M [00:01<00:00, 62.3MB/s]
# Ultralytics YOLOv8.0.26 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import datetime

# %%
date = datetime.datetime.now()

# %%
date
# Out:
# datetime.datetime(2023, 5, 31, 17, 36, 39, 356911)

# %%
file_name = f'{date.year}-{date.month}-{date.day}_{date.hour+3}_{date.minute}_run'

# %%
import os

# %%
os.rename("runs",file_name)

# %%
files.download(f'/content/{file_name}')

# %%
from google.colab import files
files.download(f'/content/{file_name}/detect/train/weights/best.pt')
